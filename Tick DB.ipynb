# %% [markdown]
# This notebook takes a Mountain Project route tick list URL, downloads it, and scrapes it for important data:
# date,
# route name,
# status of the send (Onsight, flash, send, attempt, etc.)

# %%
import sqlite3 as sl
import requests
from bs4 import BeautifulSoup
import json
import re
import numpy as np

con = sl.connect('my-test2.db')

# %% [markdown]
# # found the element that contains the tick's route name...
#
# <a class="text-black route-row" href="https://www.mountainproject.com/route/111945454/chicago-love-affair>
#     is the line for routes

# %% [markdown]
# # have to find the number of pages in the tick lists. there's a few ways to do this but this way seems most robust. there's a little pagination div at the bottom of each tick list page.......
#
# <a class="no-click">
#         1 of 3
#     </a>
# <a href="https://www.mountainproject.com/user/200166625/patrick-cheng/ticks?page=2">
# <img alt="Next" class="skinny" src="/img/arrows/next.svg"/>
# </a>
# <a href="https://www.mountainproject.com/user/200166625/patrick-cheng/ticks?page=3">
# <img alt="Last" src="/img/arrows/last.svg"/>
#
#     the page numbers
#     couple ways to find the number of tick pages:
#     find the no-click class that matches a regex expression of 'digit of digit'
#     actually that's probably the easiest way
#     other way is to find the link element but that will take more code
#     or you can just iterate until you get a 404- might be the easiest and also most robust......

# %%
def getStatus(string):
    if string == '': return ''
    poss = {'Solo', 'TR', 'Follow', 'Lead', 'Lead / Onsight', 'Lead / Flash', 'Lead / Redpoint', 'Lead / Pinkpoint', 'Lead / Fell/Hung'}
    
    meta = re.split(r'\.', string)[0]
    if (meta not in poss): return ''
    return meta

def getLastPage(url):
    page = requests.get(url)
    tickSoup = BeautifulSoup(page.content, 'html.parser')
    li = tickSoup.find_all('a', class_ = 'no-click')
    noclick = [route.text for route in li]
    p = re.compile(r'\d+')
    for el in noclick:
        if p.findall(el):
            lastPage = p.findall(el)[1]
            break
    return int(lastPage)

def getPageURL(i, url):
    ext = '' if i == 1 else ('?page=%d' %i)
    url = url + ext
    return url

def getTickInfo(tick):
    url = tick['href']
    
    info = re.split(r'[·]',tick.find('i').text)
    date = info[0].strip()
    
    if len(info) > 1:
        status = getStatus(info[1].strip())
    else: 
        status = ''
        
    return (url, date, status)

def getPageTicks(url):
    pageTicks = []
    page = requests.get(url)
    tickSoup = BeautifulSoup(page.content, 'html.parser')
    userRoutes = tickSoup.find_all('a', class_ = 'route-row')
    
    for route in userRoutes:
        info = getTickInfo(route)
        pageTicks.append(info)
        
    return pageTicks

def getUserTicks(url):
    userTicks = []
    
    for i in range(1, getLastPage(url)+1):
        pageurl = getPageURL(i, url)
        pageTicks = getPageTicks(pageurl)
        userTicks+=pageTicks
        
    return userTicks

def insertTicks(userTicks):
    for tick in userticks:
            with con:
                con.execute('insert into ticks (url, date, status) values(?, ?, ?)', tick)

# %%
# load my own ticks
url = ('https://www.mountainproject.com/user/200166625/patrick-cheng/ticks')
userticks = getUserTicks(url)
print(len(userticks))
print(userticks[80])
# Out:
# 106
# ('https://www.mountainproject.com/route/106314933/blowing-smoke-at-the-monkey', 'Jun 30, 2019', '')

# %%
# see what the table looks like...
with con:
    data = con.execute('select * from ticks where rowid < 10')
    for row in data:
        print(row)
# Out:
# ('https://www.mountainproject.com/route/105740981/rye-crisp', 'Mar 9, 2021', 'Lead / Fell/Hung')
# ('https://www.mountainproject.com/route/105803570/pure-palm', 'Mar 9, 2021', 'Solo')
# ('https://www.mountainproject.com/route/109399939/blade-runner', 'Dec 5, 2020', 'Lead / Fell/Hung')
# ('https://www.mountainproject.com/route/111183004/wretched-love-affair', 'Nov 28, 2020', 'Lead / Onsight')
# ('https://www.mountainproject.com/route/111945454/chicago-love-affair', 'Oct 19, 2020', 'Lead / Onsight')
# ('https://www.mountainproject.com/route/105889245/quasar', 'Oct 17, 2020', 'Lead / Onsight')
# ('https://www.mountainproject.com/route/105791785/cruel-sister', 'Oct 17, 2020', 'Lead / Onsight')
# ('https://www.mountainproject.com/route/105901816/azog', 'Oct 16, 2020', 'Lead / Onsight')
# ('https://www.mountainproject.com/route/109565046/puck', 'Oct 16, 2020', 'Lead / Onsight')

# %%
# sanity check print out the tick list joined with the route database for more info
with con:
    data = con.execute('SELECT date, ticks.url, grade, status, latitude, longitude FROM ticks INNER JOIN routes ON routes.url = ticks.url;')
    for row in data:
        print(row)
# Out:
# ('Mar 9, 2021', 'https://www.mountainproject.com/route/105740981/rye-crisp', 5.8, 'Lead / Fell/Hung', 42.06738673, -113.70893731)
# ('Mar 9, 2021', 'https://www.mountainproject.com/route/105803570/pure-palm', '5.11a', 'Solo', 44.36798221, -121.1308092)
# ('Dec 5, 2020', 'https://www.mountainproject.com/route/109399939/blade-runner', '5.12c', 'Lead / Fell/Hung', 47.43113857, -121.61999578)
# ('Nov 28, 2020', 'https://www.mountainproject.com/route/111183004/wretched-love-affair', '5.11c', 'Lead / Onsight', 45.53735198, -122.3720833)
# ('Oct 19, 2020', 'https://www.mountainproject.com/route/111945454/chicago-love-affair', '5.10b', 'Lead / Onsight', 44.36581163, -121.12983902)
# ('Oct 17, 2020', 'https://www.mountainproject.com/route/105889245/quasar', '5.10a/b', 'Lead / Onsight', 44.36732719, -121.13064751)
# ('Oct 17, 2020', 'https://www.mountainproject.com/route/105791785/cruel-sister', '5.10a', 'Lead / Onsight', 44.36732719, -121.13064751)
# ('Oct 16, 2020', 'https://www.mountainproject.com/route/105901816/azog', 5.9, 'Lead / Onsight', 44.3668006, -121.12998275)
# ('Oct 16, 2020', 'https://www.mountainproject.com/route/109565046/puck', '5.10a/b', 'Lead / Onsight', 44.3668006, -121.12998275)
# ('Oct 16, 2020', 'https://www.mountainproject.com/route/105803570/pure-palm', '5.11a', 'Lead / Onsight', 44.36798221, -121.1308092)
# ('Oct 16, 2020', 'https://www.mountainproject.com/route/105803718/gruff', '5.10a', 'Lead / Onsight', 44.36798221, -121.1308092)
# ('Oct 16, 2020', 'https://www.mountainproject.com/route/105804599/bad-finger', '5.10b', 'Lead / Onsight', 44.36798221, -121.1308092)
# ('Jun 30, 2019', 'https://www.mountainproject.com/route/105717307/north-chimney', 5.9, 'Lead / Onsight', 38.65144971, -109.36774785)
# ('Jun 30, 2019', 'https://www.mountainproject.com/route/106314933/blowing-smoke-at-the-monkey', '5.11a/b', '', 30.36230265, -98.12499969)
# ('Jun 30, 2019', 'https://www.mountainproject.com/route/106366831/cliptomania', '5.11a', 'Lead / Onsight', 30.36449618, -98.12640107)
# ('Jun 30, 2019', 'https://www.mountainproject.com/route/107499445/arborcidal-tendencies', '5.11b', 'Lead / Pinkpoint', 30.36449618, -98.12640107)
# ('Oct 31, 2018', 'https://www.mountainproject.com/route/105811221/nobody-here-gets-out-alive', 'V2', '', 31.92213523, -106.04391842)
# ('Oct 31, 2018', 'https://www.mountainproject.com/route/105865349/liposuction', '5.12a', 'Lead / Redpoint', 30.36310101, -98.12369714)
# ('Sep 30, 2018', 'https://www.mountainproject.com/route/105830204/pocket-puzzle', '5.10a', '', 33.31039835, -111.067558)
# ('Aug 4, 2018', 'https://www.mountainproject.com/route/105924140/gunsight-to-south-peak', 5.4, 'Lead / Onsight', 38.83452962, -79.36676621)
# ('Jun 30, 2018', 'https://www.mountainproject.com/route/105721828/walk-on-the-wild-side', 5.8, '', 33.99445878, -116.14002101)
# ('Jun 30, 2018', 'https://www.mountainproject.com/route/107455484/star-belly-sneeches', '5.10b/c', '', 30.36230265, -98.12499969)
# ('Jun 30, 2018', 'https://www.mountainproject.com/route/105886196/prototype', '5.10c', 'Lead / Redpoint', 30.36230265, -98.12499969)
# ('Jun 30, 2018', 'https://www.mountainproject.com/route/111479430/tree-gnome', '5.10c', '', 30.36640288, -98.12870075)
# ('Jun 30, 2018', 'https://www.mountainproject.com/route/108479621/freedom-fries', '5.10a/b', '', 30.36640288, -98.12870075)
# ('Jun 30, 2018', 'https://www.mountainproject.com/route/108797279/ezras-shelf', '5.10d', '', 30.36640288, -98.12870075)
# ('Jun 30, 2018', 'https://www.mountainproject.com/route/109905358/monkey-boy', '5.10c', '', 30.36640288, -98.12870075)
# ('Jun 30, 2018', 'https://www.mountainproject.com/route/107377867/go-for-the-jugular', '5.10a', '', 30.36640288, -98.12870075)
# ('Jun 30, 2018', 'https://www.mountainproject.com/route/109769538/antonian', 5.8, '', 30.36640288, -98.12870075)
# ('Jun 30, 2018', 'https://www.mountainproject.com/route/106403023/peewees-big-adventure', '5.11c', 'Lead / Flash', 30.25440244, -97.79379983)
# ('Jun 30, 2018', 'https://www.mountainproject.com/route/106274551/hysteria', '5.11b', 'Lead / Redpoint', 30.25459643, -97.79351237)
# ('Jun 30, 2018', 'https://www.mountainproject.com/route/112934700/wowie-zowie', '5.10d', 'Lead / Onsight', 30.25459643, -97.79351237)
# ('Mar 31, 2018', 'https://www.mountainproject.com/route/105868000/rock-wars', '5.10a', 'Lead / Redpoint', 37.84459855, -83.66860047)
# ('Feb 28, 2018', 'https://www.mountainproject.com/route/105871977/bedtime-for-bonzo', 5.6, 'Lead', 37.83688719, -83.64820872)
# ('Feb 28, 2018', 'https://www.mountainproject.com/route/111084937/bonzos-revenge', 5.4, 'Lead', 37.83768177, -83.64701396)
# ('Feb 28, 2018', 'https://www.mountainproject.com/route/105919554/snake', 5.8, 'Lead', 37.83768177, -83.64701396)
# ('Feb 28, 2018', 'https://www.mountainproject.com/route/106129927/calypso-i', 5.7, 'Lead', 37.83722773, -83.64710379)
# ('Feb 28, 2018', 'https://www.mountainproject.com/route/105870326/party-time', 5.7, 'Lead', 40.67778794, -111.57730701)
